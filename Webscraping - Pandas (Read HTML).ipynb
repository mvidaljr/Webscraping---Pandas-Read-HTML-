# %%
import urllib.request

# %%
get_url = urllib.request.urlopen('https://www.starlimpo.com.br')

# %%
print(get_url)

# %%
page_html = get_url.read()
print(page_html)
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html lang=pt-BR>\n<head>\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta name="robots" content="index,follow">\n\n  <title>Starlimpo - HOME</title>\n\n  \n  \n  \n  \n\n  <meta name="description" content="Remover picha\xc3\xa7\xc3\xb5es">\n\n  <meta property="og:title" content="Starlimpo - HOME">\n  <meta property="og:description" content="Remover picha\xc3\xa7\xc3\xb5es">\n  <meta property="og:locale" content="pt_BR">\n  <meta property="og:type" content="website">\n  <meta property="og:url" content="https://www.starlimpo.com.br/">\n  \n\n  <link rel="icon" type="image/png" href="https://yata2.s3-object.locaweb.com.br/6b5672b933b316edd8083732b7415451846f09dceff26e3b949ae3d622a96b3e">\n\n  <link href=\'//fonts.googleapis.com/css?family=Open Sans:400,600,700|Roboto:400,700|Roboto:400,700|Robot
# ...

# %%
import pandas as pd

get_table = pd.read_html('https://en.wikipedia.org/wiki/FIFA_World_Cup')
get_table[0].head(10)
# Out:
#                          0                         1
# 0                      NaN                       NaN
# 1          Organising body                      FIFA
# 2                  Founded        1930; 92 years ago
# 3                   Region             International
# 4          Number of teams               32 (finals)
# 5        Current champions  France (2nd title)(2018)
# 6  Most successful team(s)         Brazil (5 titles)
# 7  Television broadcasters      List of broadcasters
# 8                  Website         fifa.com/worldcup
# 9      2022 FIFA World Cup       2022 FIFA World Cup

# %%
get_table[3].head(10)
# Out:
#    Year         Hosts Venues/Cities Totalattendance † Matches Avg.attendance  \
#    Year         Hosts Venues/Cities Totalattendance † Matches Avg.attendance
# 0  1930       Uruguay           3/1            590549      18          32808
# 1  1934         Italy           8/8            363000      17          21353
# 2  1938        France          10/9            375700      18          20872
# 3  1950        Brazil           6/6           1045246      22          47511
# 4  1954   Switzerland           6/6            768607      26          29562
# 5  1958        Sweden         12/12            819810      35          23423
# 6  1962         Chile           4/4            893172      32          27912
# 7  1966       England           8/7           1563135      32          48848
# 8  1970        Mexico           5/5           1603975      32          50124
# 9  1974  West Germany           9/9           1865753      38          49099
#
# ...
